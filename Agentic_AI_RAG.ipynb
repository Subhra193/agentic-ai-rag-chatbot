# %%
#Install Dependencies
# !pip install -U \
    langchain \
    langchain-community \
    langchain-openai \
    langgraph \
    pinecone-client \
    pypdf \
    fastapi \
    uvicorn
# Out:
# Requirement already satisfied: langchain in c:\users\subhra\anaconda3\lib\site-packages (1.2.7)
# Requirement already satisfied: langchain-community in c:\users\subhra\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-openai in c:\users\subhra\anaconda3\lib\site-packages (1.1.7)
# Requirement already satisfied: langgraph in c:\users\subhra\anaconda3\lib\site-packages (1.0.7)
# Requirement already satisfied: pinecone-client in c:\users\subhra\anaconda3\lib\site-packages (6.0.0)
# Requirement already satisfied: pypdf in c:\users\subhra\anaconda3\lib\site-packages (6.6.2)
# Collecting fastapi
#   Downloading fastapi-0.128.0-py3-none-any.whl.metadata (30 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.40.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.7 in c:\users\subhra\anaconda3\lib\site-packages (from langchain) (1.2.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\subhra\anaconda3\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\subhra\anaconda3\lib\site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\subhra\anaconda3\lib\site-packages (from langgraph) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\subhra\anaconda3\lib\site-packages (from langgraph) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\subhra\anaconda3\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.6.7)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.7->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\subhra\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\subhra\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\subhra\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\subhra\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.6)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\subhra\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\subhra\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\subhra\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\subhra\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.7.0)
# Requirement already satisfied: certifi in c:\users\subhra\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\subhra\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\subhra\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\subhra\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\subhra\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\subhra\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\subhra\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-community) (3.11.10)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\subhra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\subhra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\subhra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\subhra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\subhra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\subhra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\subhra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\subhra\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\subhra\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\subhra\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\subhra\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\subhra\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\subhra\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\subhra\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-openai) (2.16.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\subhra\anaconda3\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\subhra\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\subhra\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\subhra\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\subhra\anaconda3\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\subhra\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2024.11.6)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\subhra\anaconda3\lib\site-packages (from pinecone-client) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\subhra\anaconda3\lib\site-packages (from pinecone-client) (2.9.0.post0)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: click>=7.0 in c:\users\subhra\anaconda3\lib\site-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: colorama in c:\users\subhra\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\subhra\anaconda3\lib\site-packages (from python-dateutil>=2.5.3->pinecone-client) (1.17.0)
# Downloading fastapi-0.128.0-py3-none-any.whl (103 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Installing collected packages: annotated-doc, uvicorn, starlette, fastapi
#
#    ---------- ----------------------------- 1/4 [uvicorn]
#    ---------- ----------------------------- 1/4 [uvicorn]
#    ---------- ----------------------------- 1/4 [uvicorn]
#    -------------------- ------------------- 2/4 [starlette]
#    -------------------- ------------------- 2/4 [starlette]
#    -------------------- ------------------- 2/4 [starlette]
#    ------------------------------ --------- 3/4 [fastapi]
#    ------------------------------ --------- 3/4 [fastapi]
#    ------------------------------ --------- 3/4 [fastapi]
#    ---------------------------------------- 4/4 [fastapi]
#
# Successfully installed annotated-doc-0.0.4 fastapi-0.128.0 starlette-0.50.0 uvicorn-0.40.0

# %%
#Imports & Environment Setup
import os
from typing import TypedDict, List

from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

from langchain_openai import OpenAIEmbeddings, ChatOpenAI

from langchain_community.vectorstores import Pinecone
import pinecone

from langgraph.graph import StateGraph

# %%
#Load PDF
PDF_PATH = "Ebook-Agentic-AI.pdf"

loader = PyPDFLoader(PDF_PATH)
documents = loader.load()

len(documents)

# %%
#Chunk the PDF
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=150
)

chunks = text_splitter.split_documents(documents)
len(chunks)

# %%
#Initialize Pinecone & Store Embeddings


INDEX_NAME = "agentic-ai-rag"

existing_indexes = [index.name for index in pc.list_indexes()]

if INDEX_NAME not in existing_indexes:
    pc.create_index(
        name=INDEX_NAME,
        dimension=1536,   # OpenAI embedding size
        metric="cosine"
    )

# %%
embeddings = OpenAIEmbeddings()

vectorstore = Pinecone.from_documents(
    documents=chunks,
    embedding=embeddings,
    index_name=INDEX_NAME
)

# %%
#Define RAG State (LangGraph)
class RAGState(TypedDict):
    question: str
    context: List
    answer: str

# %%
#Retriever Node
def retrieve(state: RAGState):
    query = state["question"]

    db = Pinecone.from_existing_index(
        index_name=INDEX_NAME,
        embedding=embeddings
    )

    docs = db.similarity_search(query, k=4)

    return {
        "context": docs,
        "question": query
    }

# %%
#Generator Node (Strict Grounding)
llm = ChatOpenAI(
    model="gpt-4",
    temperature=0
)

PROMPT_TEMPLATE = """
You are an AI assistant.
Answer the question ONLY using the context provided.
If the answer is not present, respond exactly with:
"I don't know based on the provided document."

Context:
{context}

Question:
{question}
"""

def generate(state: RAGState):
    context_text = "\n\n".join(
        [doc.page_content for doc in state["context"]]
    )

    prompt = PROMPT_TEMPLATE.format(
        context=context_text,
        question=state["question"]
    )

    answer = llm.predict(prompt)

    return {
        "answer": answer,
        "context": state["context"]
    }

# %%
#Build LangGraph Pipeline
workflow = StateGraph(RAGState)

workflow.add_node("retrieve", retrieve)
workflow.add_node("generate", generate)

workflow.set_entry_point("retrieve")
workflow.add_edge("retrieve", "generate")

rag_graph = workflow.compile()

# %%
#Test the RAG Chatbot
query = "What is Agentic AI?"

result = rag_graph.invoke({"question": query})

print("ANSWER:\n", result["answer"])
print("\n--- Retrieved Contexts ---\n")

for i, doc in enumerate(result["context"], 1):
    print(f"[Chunk {i}]")
    print(doc.page_content[:500])
    print("-" * 80)

# %%
#Confidence Score (Simple)
confidence = round(1 / len(result["context"]), 2)
confidence
